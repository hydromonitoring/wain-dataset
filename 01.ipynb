# %%
import pandas as pd
df = pd.read_excel("dams.xlsx")
df
# Out:
#      Station ID   Station Name River Basin Name  Latitude (°)  Longitude (°)  \
# 0         S1127      Akhuapada         Brahmani       20.9167        86.2794
# 1         S1129         Altuma         Brahmani       20.9308        85.5192
# 2         S1130      Ananadpur         Brahmani       21.2106        86.1197
# 3         S1150      Belbahali         Brahmani       21.1378        86.1164
# 4         S1132        BHADRAK         Brahmani       21.0678        86.5036
# ...         ...            ...              ...           ...            ...
# 4322      S3194        Waghera       West_Coast       20.0628        73.5033
# 4323      S3196      Waghiwali       West_Coast       19.5500        73.2000
# 4324      S2554      Yennehole       West_Coast       13.2942        74.9806
# 4325      S4637          Gadat             Tapi       20.8581        72.9850
# 4326      S4628  Neeleswaram_2       West_Coast       10.1220        76.4020
#
# ...

# %%
df.columns
# Out:
# Index(['Station ID', 'Station Name', 'River Basin Name', 'Latitude (°)',
#        'Longitude (°)', 'Area (km²)', 'Perimeter (km)', 'Circularity Ratio',
#        'Minimum Elevation (m)', 'Maximum Elevation (m)', 'Mean Elevation (m)',
#        'Mean Slope (m/km)', 'Mean Precipitation Rate (mm/day)',
#        'Maximum Temperature (°C)', 'Minimum Temperature (°C)',
#        'High Precipitation Frequency (days/year)',
#        'Low Precipitation Frequency (days/year)', 'High Precipitation Season',
#        'Low Precipitation Season', 'High Precipitation Spell (days)',
#        'Low Precipitation Spell (days)', 'Aridity Index', 'Seasonality',
#        'Dominant Lithological Class',
#        'Area Covered by Dominant Lithological Class',
#        'Second Dominant Lithological Class',
#        'Area Covered by Second Dominant Lithological Class',
#        'Subsurface Permeability (m², log scale)', 'Subsurface Porosity',
#        'Groundwater Mean Level (m)', 'Dominant LULC Class',
# ...

# %%
df['Q5 (m³/sec)'].describe()
# Out:
# count    160.000000
# mean       8.899241
# std       27.092474
# min        0.000000
# 25%        0.000000
# 50%        0.154875
# 75%        3.013750
# max      197.090000
# Name: Q5 (m³/sec), dtype: float64
